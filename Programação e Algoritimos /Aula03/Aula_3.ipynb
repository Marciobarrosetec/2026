# %% [markdown]
# <a href="https://colab.research.google.com/github/Marciobarrosetec/2026/blob/main/Programa%C3%A7%C3%A3o%20e%20Algoritimos%20/Aula03/Aula_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de Progrmação e Algoritímos
#
# * Introdução a programação

# %%
print ("olá mundo")
# Out:
# olá mundo

# %% [markdown]
# Soma de 02 números

# %%
a = 5
b = 6
t = a + b

# %%
print (t)
# Out:
# 11

# %%
nome = "Márcio" # str
idade = 25 # int
altura = 1.8 # float

numero_complexo = 2 + 3j

# %%
print (f"Nome: {nome}, Idade: {idade}, Altura: {altura}")
# Out:
# Nome: Márcio, Idade: 25, Altura: 1.8
